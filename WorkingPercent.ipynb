# %%
import time
import cv2
import mediapipe as mp
from collections import deque
import statistics

# %%
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %%
# Initialize webcam
# cap = cv2.VideoCapture(".\PoseEstimation01.mp4")
cap = cv2.VideoCapture(0)

# Time and frame counters
start_time = time.time()
total_frames = 0
working_frames = 0

# Smoothing
activity_queue = deque(maxlen=10)
prev_left_hand = None
prev_right_hand = None

with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        total_frames += 1

        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        results = pose.process(image)

        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

        activity = "Unknown"
        working = False

        if results.pose_landmarks:
            landmarks = results.pose_landmarks.landmark
            left_hip = landmarks[mp_pose.PoseLandmark.LEFT_HIP]
            left_knee = landmarks[mp_pose.PoseLandmark.LEFT_KNEE]
            left_shoulder = landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER]
            left_hand = landmarks[mp_pose.PoseLandmark.LEFT_WRIST]
            right_hand = landmarks[mp_pose.PoseLandmark.RIGHT_WRIST]

            hip_knee_diff = abs(left_hip.y - left_knee.y)
            shoulder_hip_diff = abs(left_shoulder.y - left_hip.y)
            hand_diff = abs(left_hand.x - right_hand.x)

            pose_ratio = hip_knee_diff / (shoulder_hip_diff + 1e-5)

            if pose_ratio < 0.6 and hand_diff < 0.1:
                posture = "Sitting"
                idle = True
            elif pose_ratio < 0.6:
                posture = "Sitting"
                idle = False
            elif hand_diff < 0.1 and shoulder_hip_diff < 0.65:
                posture = "Standing"
                idle = True
            else:
                posture = "Standing"
                idle = False

            if prev_left_hand is not None and prev_right_hand is not None:
                left_movement = abs(left_hand.x - prev_left_hand[0]) + abs(left_hand.y - prev_left_hand[1])
                right_movement = abs(right_hand.x - prev_right_hand[0]) + abs(right_hand.y - prev_right_hand[1])
                if left_movement > 0.02 or right_movement > 0.02:
                    working = True

            prev_left_hand = (left_hand.x, left_hand.y)
            prev_right_hand = (right_hand.x, right_hand.y)

            if idle and not working:
                activity = f"{posture} + Idle"
            elif working:
                activity = f"{posture} + Working"
            else:
                activity = posture

            if working:
                working_frames += 1

            activity_queue.append(activity)
            stable_activity = statistics.mode(activity_queue)
        else:
            stable_activity = "No Person Detected"

        cv2.putText(image, stable_activity, (30, 50), cv2.FONT_HERSHEY_SIMPLEX,
                    1, (0, 255, 0), 2, cv2.LINE_AA)

        cv2.imshow('Worker Pose & Activity Detection', image)

        if cv2.waitKey(5) & 0xFF == 27:
            break

# End of video processing
cap.release()
cv2.destroyAllWindows()

end_time = time.time()
elapsed_time_sec = end_time - start_time
video_duration = elapsed_time_sec
fps = total_frames / elapsed_time_sec
working_percentage = (working_frames / total_frames) * 100 if total_frames else 0

print(f"\n[RESULT]")
print(f"Total Frames Processed: {total_frames}")
print(f"Working Frames Detected: {working_frames}")
print(f"Video Duration: {video_duration:.2f} seconds")
print(f"Approx FPS: {fps:.2f}")
print(f"Working Time Percentage: {working_percentage:.2f}%")
# Out:
# [RESULT]
# Total Frames Processed: 148
# Working Frames Detected: 119
# Video Duration: 15.51 seconds
# Approx FPS: 9.54
# Working Time Percentage: 80.41%
